# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# %cd gdrive/My Drive/fast transfer
# Out:
# /content/gdrive/My Drive/fast transfer

# %%
# !git clone https://github.com/lengstrom/fast-style-transfer.git
# Out:
# fatal: destination path 'fast-style-transfer' already exists and is not an empty directory.

# %%
# %cd fast-style-transfer
# Out:
# /content/gdrive/My Drive/fast transfer/fast-style-transfer

# %%
# !ls
# now upload a style checkpoint(for example this: http://video.udacity-data.com.s3.amazonaws.com/topher/2017/January/588aa846_udnie/udnie.ckpt) and an image into this directory
# Out:
# ayush.jfif   examples		   README.md	style.py
# ayush.jpg    output		   scream.ckpt	transform_video.py
# docs.md      --rain-princess.ckpt  setup.sh	udnie.ckpt
# evaluate.py  rain-princess.ckpt    src		xa.jpg

# %%
# !pip install scipy==1.1.0

# !pip install moviepy==0.2.3.3

# !pip install tensorflow==1.15.2

# !pip install pillow

# !pip install imageio-ffmpeg

# %%
# !python evaluate.py --checkpoint ./udnie.ckpt --in-path ./ayush.jfif --out-path ./ayush.jpg
# Out:
# WARNING:tensorflow:From evaluate.py:85: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From evaluate.py:88: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-23 09:41:06.976092: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-03-23 09:41:06.979520: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-03-23 09:41:06.979733: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x16872c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-23 09:41:06.979762: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING:tensorflow:From evaluate.py:90: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...
